# %%
import yfinance as yf 
import numpy as np
import pandas as pd

# %% [markdown]
# # data download

# %%
symbol = "^NSEI"

download = yf.download(symbol, "2025-03-01", "2025-08-01")

data.to_csv(f"{symbol}.csv")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4196\2438747835.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   download = yf.download(symbol, "2025-03-01", "2025-08-01")
# [*********************100%***********************]  1 of 1 completed

# %%
data = pd.read_csv("^NSEI.csv")

# %%
opens = np.array(data['Open'])
print(opens)
# Out:
# ['^NSEI' nan '22194.55078125' '21974.44921875' '22073.05078125'
#  '22476.349609375' '22508.650390625' '22521.849609375' '22345.94921875'
#  '22536.349609375' '22541.5' '22353.150390625' '22662.25' '22874.94921875'
#  '23036.599609375' '23168.25' '23515.400390625' '23751.5' '23700.94921875'
#  '23433.94921875' '23600.400390625' '23341.099609375' '23192.599609375'
#  '23150.30078125' '23190.400390625' '21758.400390625' '22446.75'
#  '22460.30078125' '22695.400390625' '23368.349609375' '23344.099609375'
#  '23401.849609375' '23949.150390625' '24185.400390625' '24357.599609375'
#  '24277.900390625' '24289.0' '24070.25' '24370.69921875' '24342.05078125'
#  '24311.900390625' '24419.5' '24500.75' '24233.30078125' '24431.5'
#  '23935.75' '24420.099609375' '24864.05078125' '24613.80078125'
#  '24694.44921875' '25064.650390625' '25005.349609375' '24996.19921875'
#  '24744.25' '24733.94921875' '24639.5' '24919.349609375' '24956.650390625'
# ...

# %%
download['Daily Return'] = download[('Close', symbol)].pct_change()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.histplot(download[('Daily Return', )])
plt.title(f"{symbol} Daily Returns Distribution")
plt.xlabel("Daily Return")
plt.ylabel("Frequency")
# plt.grid(True)
plt.show()

# %%
.dropna(), bins=50, kde=True, color='purple')
